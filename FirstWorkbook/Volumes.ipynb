-- %%
create volume dev_ext.bronze.managed_vol
comment 'This is a managed volume'
;

-- %%
desc volume dev_ext.bronze.managed_vol

-- %%
%sh
ls -ltr .

-- %%
%sh

wget https://github.com/delhilife/subhamkharwal_pyspark-zero-to-hero/blob/master/examples/emp.csv

-- %%
%sh
pwd

-- %%
%python
dbutils.fs.mkdirs("/Volumes/dev_ext/bronze/external_vol/files")

-- %%
select * from csv. `/Volumes/dev_ext/bronze/managed_vol/files/emp.csv`

-- %%
-- Create external volume

create external volume dev_ext.bronze.external_vol
comment 'This is a external volume'
location 's3://revz-devext-catalog/ext_volume'
;

-- %%
desc volume dev_ext.bronze.external_vol

-- %%
%python

dbutils.fs.cp("/Volumes/dev_ext/bronze/managed_vol/files/emp.csv", "/Volumes/dev_ext/bronze/external_vol/files" )

-- %%
drop volume dev_ext.bronze.external_vol

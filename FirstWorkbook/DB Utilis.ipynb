# %%
dbutils.help()

# %%
dbutils.fs.help()

# %%
dbutils.fs.ls("s3://revz-devext-catalog/ext_volume/files/")

# %%
display(dbutils.fs.ls("/Volumes/dev_ext/bronze/external_vol"))

# %%
display(dbutils.fs.head("dbfs:/Volumes/dev_ext/bronze/external_vol/files/emp.csv"))

# %%
dbutils.widgets.text("input_id", "1000", "Cust_id")

# %%
dbutils.widgets.get("input_id")

# %%
# %sql
select :input_id

# %%
dbutils.secrets.help()

# %%
dbutils.notebook.help()

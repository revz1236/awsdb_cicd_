-- %%
%sql 
show catalogs like '*v*'

-- %%
show schemas in dev_ext

-- %%
show tables in dev_ext.bronze like '*sale*'

-- %%
%python

spark.catalog.tableExists('dev_ext.bronze.raw_sale_1')

-- %%
create table if not exists dev_ext.bronze.emp (
  emp_id int, 
  emp_name string, 
  dept string, 
  salary double
);

-- %%
insert into dev_ext.bronze.emp (emp_id, name, dept, salary) values (1001, 'Revanth', 'D101', 25000);
insert into dev_ext.bronze.emp (emp_id, name, dept, salary) values (1002, 'Prasanna', 'D101', 35000);
insert into dev_ext.bronze.emp (emp_id, name, dept, salary) values (1003, 'Harish', 'D102', 55000);
insert into dev_ext.bronze.emp (emp_id, name, dept, salary) values (1004, 'Jaswanth', 'D103', 15000);

-- %%
select * from dev_ext.bronze.emp;

-- %%
DESCRIBE HISTORY dev_ext.bronze.emp

-- %%
desc extended dev_ext.bronze.emp

-- %%
-- Create Temp and permanent views

create temporary view dev_ext.bronze.emp_tmp_vw as select * from dev_ext.bronze.emp where dept = 'D101';

-- %%
select * from emp_tmp_vw

-- %%
create or replace view dev_ext.bronze.emp_perm_vw as select * from dev_ext.bronze.emp where dept = 'D103';

-- %%
select * from dev_ext.bronze.emp_perm_vw;

-- %%
CREATE TABLE dev_ext.bronze.emp_ctas as SELECT * from dev_ext.bronze.emp;

-- %%
select * from dev_ext.bronze.emp_ctas

-- %%
DESC EXTENDED dev_ext.bronze.emp_ctas

-- %%
DESC HISTORY dev_ext.bronze.emp_ctas

-- %%
CREATE  TABLE dev_ext.bronze.emp_dc deep CLONE dev_ext.bronze.emp

-- %%
desc extended dev_ext.bronze.emp_dc

-- %%
desc history dev_ext.bronze.emp_dc

-- %%
create table dev_ext.bronze.emp_sc as select * from dev_ext.bronze.emp

-- %%
desc extended dev_ext.bronze.emp_sc

-- %%
create table dev_ext.bronze.emp_sc1 shallow clone dev_ext.bronze.emp

-- %%
desc extended  dev_ext.bronze.emp_sc1

-- %%
desc history dev_ext.bronze.emp_sc1

-- %%
select * from dev_ext.bronze.emp_sc1

-- %%
insert into dev_ext.bronze.emp (emp_id, name, dept, salary) values (1005, 'Raju', 'D102', 45000);

-- %%
select * from dev_ext.bronze.emp

-- %%
select * from dev_ext.bronze.emp_sc1

-- %%
insert into dev_ext.bronze.emp_sc1 (emp_id, name, dept, salary) values (1006, 'Gann', 'D103', 35000);

-- %%
desc history dev_ext.bronze.emp_sc1

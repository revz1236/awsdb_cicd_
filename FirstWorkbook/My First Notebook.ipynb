# %% [markdown]
# # My First Notebook

# %%
spark

# %%
spark.range(0,10).show()

# %%
# %sql

show databases

# %%
# %sh
pwd

# %%
a=10

# %%
display(_sqldf)

# %%
# %sql
describe catalog extended revzwithdata

# %%
# Create external location

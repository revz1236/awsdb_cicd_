# %%
 # %sql 

desc catalog extended revzwithdata

# %%
# %sql
create catalog dev_sql

# %%
# %sql
-- External location catalog

create catalog dev_ext
managed location 's3://revz-devext-catalog/catalog'
comment 'This is external storage catalog'
;

# %%
# %sql
desc catalog extended dev_ext;

# %%
# %sql
create external location `ext_catalog`
url 's3://revz-devext-catalog/catalog/'
with (storage credential `db_s3_credentials_databricks-s3-ingest-3af04`)
;

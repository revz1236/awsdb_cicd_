-- %%
%sql

create schema if not exists dev_ext.bronze
comment 'This is the bronze schema under external location for catalog dev_ext'
;

-- %%
%sql

create external location `ext_schema`
url 's3://revz-devext-catalog/schemas/'
with (storage credential `db_s3_credentials_databricks-s3-ingest-3af04`)
;

-- %%
%sql 
create schema if not exists dev_ext.bronze_ext
managed location 's3://revz-devext-catalog/schemas/'
comment 'This is the bronze external schema under external location for catalog dev_ext'
;

-- %%
create table dev_ext.bronze_ext.raw_sale(
  invoice_id string,
  cust_id string,
  prod_code string,
  QTY double,
  price double
);

insert into dev_ext.bronze_ext.raw_sale values("INV1001", 'CUST1001', 'PCODE1001', 10, 100);

-- %%
DESC EXTENDED dev_ext.bronze_EXT.raw_sale;

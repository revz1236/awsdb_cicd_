-- %%
create table dev_ext.bronze.managed_sale(
  invoice_id string,
  cust_id string,
  prod_code string,
  QTY double,
  price double
);

insert into dev_ext.bronze.managed_sale values("INV1001", 'CUST1001', 'PCODE1001', 10, 100);

-- %%
create table dev_ext.bronze.external_sale(
  invoice_id string,
  cust_id string,
  prod_code string,
  QTY double,
  price double
)
location 's3://revz-devext-catalog/ext_tables/'
;

insert into dev_ext.bronze.external_sale values("INV1001", 'CUST1001', 'PCODE1001', 10, 100);

-- %%
drop table dev_ext.bronze.managed_sale;

-- %%
use catalog dev_ext;

SHOW TABLES dropped IN bronze;

-- %%
undrop table dev_ext.bronze.managed_sale;

-- %%
drop table dev_ext.bronze.external_sale;

-- %%
use catalog dev_ext;

show tables dropped in dev_ext.bronze;

-- %%
undrop table with id 'd3b415b9-c8e2-4a6e-81a3-40094f405e14';
